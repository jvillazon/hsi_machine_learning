# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from tkinter import Tk, filedialog

# %%
root = Tk()
root.withdraw()
root.call('wm', 'attributes', '.', '-topmost', True)
sample = filedialog.askopenfilename(multiple=True)
image = io.imread(sample[0])
# Out:
# 2025-05-09 20:19:16.093 python[24232:3322102] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-05-09 20:19:16.374 python[24232:3322102] The class 'NSOpenPanel' overrides the method identifier.  This method is implemented by class 'NSWindow'

# %%
plt.plot(image[:, 121,121])
